# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
ax = sns.lineplot(x=df.index, y="income", data=df)

# %%
df2 = pd.read_csv("..\data\dataset_209770_6.txt", sep=' ')

# %%
df2.head()
# Out:
#             x            y
# 0  293.601161  1295.939680
# 1  622.831910   696.999075
# 2  811.329153   787.711605
# 3  804.855065   800.100244
# 4  310.514510  1298.330160

# %%
df2.plot.scatter(x='x', y='y')
plt.show()

# %%
df3 = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

# %%
df3.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(data=df3, cmap='viridis')

# %%
df4 = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)

# %%
df4.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles
# 0          agi                       ['Carry', 'Escape', 'Nuker']
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
df4.dtypes
# Out:
# attack_type       object
# id                 int64
# legs               int64
# localized_name    object
# name              object
# primary_attr      object
# roles             object
# dtype: object

# %%
df4['roles_count'] = df4['roles'].apply(lambda x : len((str(x)[1:-1]).split()))

# %%
df4.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles  roles_count
# 0          agi                       ['Carry', 'Escape', 'Nuker']            3
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']            4
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']            4
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...            5
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']            4

# %%
df4.roles_count.hist()
plt.show()

# %%
df5 = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)

# %%
df5.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df5.iloc[:,:-1].plot.kde()
plt.show()

# %%
ax = sns.violinplot(x=df5["petal length"])

# %%
ax = sns.pairplot(data=df5, hue='species')
# Out:
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
